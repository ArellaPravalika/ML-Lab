# %%
#1 Import the dataset (Housing.csv) and look at the top five rows
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#2 Check the shape of the DataFrame (rows, columns)

# %%
df.shape
# Out:
# (545, 13)

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
#4 Check for missing  values if any, replace with appropriate values

# %%
df.isnull().sum()
print(df.isnull().sum())
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
#5 Prepare  X (independent variables) and y (dependent variable)

# %%
y=df.iloc[:,0]
print(y)
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
x=df.iloc[:,1:]
print(x)
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# ...

# %%
#Visualise the relationship between the independent variables and the depenedent variable using scatterplots

# %%
x=df['bedrooms'].values
y=df['price'].values
plt.scatter(x,y,color="red")
plt.show()

# %%
#7 Encoding categorical data in X

# %%
print(x)
# Out:
# [4 4 3 4 4 3 4 5 4 3 3 4 4 4 3 4 4 3 3 3 3 3 3 3 3 4 3 3 5 4 3 3 4 3 5 3 3
#  4 3 4 3 3 3 4 4 3 3 3 3 3 3 3 4 3 3 3 4 4 4 3 3 2 4 4 3 3 2 3 3 4 3 4 3 2
#  3 4 3 3 3 3 3 3 3 3 3 3 3 3 3 5 3 2 3 3 4 3 3 3 3 4 3 3 3 3 3 3 4 3 4 4 3
#  3 6 3 2 3 3 4 3 3 3 3 4 4 3 3 3 3 3 3 3 4 3 3 3 3 4 4 3 3 3 4 4 5 4 3 2 3
#  3 4 3 4 5 3 3 3 3 4 3 3 4 3 4 3 3 3 3 2 4 4 3 3 3 4 3 4 3 3 3 3 4 3 3 3 3
#  3 2 3 2 2 4 3 3 2 3 4 3 3 3 3 3 3 2 4 3 3 2 3 3 3 3 3 4 4 2 3 3 3 2 3 4 4
#  2 3 2 2 3 2 3 4 2 3 3 3 3 3 2 3 4 3 3 3 3 3 3 3 3 4 2 4 3 3 3 2 4 2 3 3 3
#  2 3 3 2 3 2 3 3 3 4 3 3 5 3 4 4 2 2 2 3 2 2 2 3 4 2 3 3 3 3 2 4 3 4 2 4 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 4 3 2 3 3 2 2 4 3 3 4 3 3 3 3 3 4 4 3 3 3 2 3 4
#  3 2 2 3 4 2 4 5 2 3 2 2 3 2 3 2 3 2 2 2 3 2 3 5 4 2 3 2 3 2 2 3 2 2 2 2 2
#  2 3 3 2 2 3 3 3 3 3 2 2 3 4 2 2 3 3 3 4 3 3 3 3 3 6 2 2 3 2 2 3 2 3 3 3 2
#  3 2 2 3 3 3 3 2 3 3 2 4 4 2 2 2 3 3 2 3 3 2 4 2 4 3 4 4 2 3 3 2 2 4 3 2 3
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['basement']=le.fit_transform(df['basement'])


print(df['basement'])
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 540    1
# 541    0
# 542    0
# 543    0
# 544    0
# Name: basement, Length: 545, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['mainroad']=le.fit_transform(df['mainroad'])


print(df['mainroad'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 540    1
# 541    0
# 542    1
# 543    0
# 544    1
# Name: mainroad, Length: 545, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['guestroom']=le.fit_transform(df['guestroom'])


print(df['guestroom'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 540    0
# 541    0
# 542    0
# 543    0
# 544    0
# Name: guestroom, Length: 545, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['hotwaterheating']=le.fit_transform(df['hotwaterheating'])


print(df['hotwaterheating'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 540    0
# 541    0
# 542    0
# 543    0
# 544    0
# Name: hotwaterheating, Length: 545, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['airconditioning']=le.fit_transform(df['airconditioning'])


print(df['airconditioning'])
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 540    0
# 541    0
# 542    0
# 543    0
# 544    0
# Name: airconditioning, Length: 545, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['prefarea']=le.fit_transform(df['prefarea'])


print(df['prefarea'])
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 540    0
# 541    0
# 542    0
# 543    0
# 544    0
# Name: prefarea, Length: 545, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#     basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
df = pd.get_dummies(df, columns=['furnishingstatus'], drop_first=True)

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#     basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['furnishingstatus_semi-furnished']=le.fit_transform(df['furnishingstatus_semi-furnished'])


print(df['furnishingstatus_semi-furnished'])
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 540    0
# 541    1
# 542    0
# 543    0
# 544    0
# Name: furnishingstatus_semi-furnished, Length: 545, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['furnishingstatus_semi-furnished']=le.fit_transform(df['furnishingstatus_semi-furnished'])


print(df['furnishingstatus_semi-furnished'])
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 540    0
# 541    1
# 542    0
# 543    0
# 544    0
# Name: furnishingstatus_semi-furnished, Length: 545, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['furnishingstatus_unfurnished']=le.fit_transform(df['furnishingstatus_unfurnished'])


print(df['furnishingstatus_unfurnished'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 540    1
# 541    0
# 542    1
# 543    0
# 544    1
# Name: furnishingstatus_unfurnished, Length: 545, dtype: int64

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#     basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
print(x)
# Out:
# [4 4 3 4 4 3 4 5 4 3 3 4 4 4 3 4 4 3 3 3 3 3 3 3 3 4 3 3 5 4 3 3 4 3 5 3 3
#  4 3 4 3 3 3 4 4 3 3 3 3 3 3 3 4 3 3 3 4 4 4 3 3 2 4 4 3 3 2 3 3 4 3 4 3 2
#  3 4 3 3 3 3 3 3 3 3 3 3 3 3 3 5 3 2 3 3 4 3 3 3 3 4 3 3 3 3 3 3 4 3 4 4 3
#  3 6 3 2 3 3 4 3 3 3 3 4 4 3 3 3 3 3 3 3 4 3 3 3 3 4 4 3 3 3 4 4 5 4 3 2 3
#  3 4 3 4 5 3 3 3 3 4 3 3 4 3 4 3 3 3 3 2 4 4 3 3 3 4 3 4 3 3 3 3 4 3 3 3 3
#  3 2 3 2 2 4 3 3 2 3 4 3 3 3 3 3 3 2 4 3 3 2 3 3 3 3 3 4 4 2 3 3 3 2 3 4 4
#  2 3 2 2 3 2 3 4 2 3 3 3 3 3 2 3 4 3 3 3 3 3 3 3 3 4 2 4 3 3 3 2 4 2 3 3 3
#  2 3 3 2 3 2 3 3 3 4 3 3 5 3 4 4 2 2 2 3 2 2 2 3 4 2 3 3 3 3 2 4 3 4 2 4 3
#  3 3 3 3 3 3 3 3 3 3 3 3 3 4 3 2 3 3 2 2 4 3 3 4 3 3 3 3 3 4 4 3 3 3 2 3 4
#  3 2 2 3 4 2 4 5 2 3 2 2 3 2 3 2 3 2 2 2 3 2 3 5 4 2 3 2 3 2 2 3 2 2 2 2 2
#  2 3 3 2 2 3 3 3 3 3 2 2 3 4 2 2 3 3 3 4 3 3 3 3 3 6 2 2 3 2 2 3 2 3 3 3 2
#  3 2 2 3 3 3 3 2 3 3 2 4 4 2 2 2 3 3 2 3 3 2 4 2 4 3 4 4 2 3 3 2 2 4 3 2 3
# ...

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom basement  \
# 0    7420         4          2        3         1          0       no
# 1    8960         4          4        4         1          0       no
# 2    9960         3          2        2         1          0      yes
# 3    7500         4          2        2         1          0      yes
# 4    7420         4          1        2         1          1      yes
# ..    ...       ...        ...      ...       ...        ...      ...
# 540  3000         2          1        1         1          0      yes
# 541  2400         3          1        1         0          0       no
# 542  3620         2          1        1         1          0       no
# 543  2910         3          1        1         0          0       no
# 544  3850         3          1        2         1          0       no
#
#      hotwaterheating  airconditioning  parking  prefarea  \
# 0                  0                1        2         1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['basement']=le.fit_transform(df['basement'])


print(df['basement'])
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 540    1
# 541    0
# 542    0
# 543    0
# 544    0
# Name: basement, Length: 545, dtype: int64

# %%
x = df.iloc[:, 1:]

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_train=regressor.predict(x_train)
diff1=(y_pred_train-y_train)
print(diff1)
# Out:
# [ 1.13525788e+06  1.22392857e+05 -7.12957392e+05 -1.10003745e+06
#  -5.89661599e+05  5.63479358e+05  1.11564512e+06  3.75091662e+05
#  -6.04319430e+05  6.03526250e+05  2.79466226e+05  4.60771331e+05
#  -3.97691379e+05  1.48683957e+06  1.42249295e+06  4.71283449e+05
#   5.09222087e+05  1.01582127e+06 -2.48229240e+06  4.13820250e+05
#  -1.53518009e+05 -1.22213231e+06 -8.70863809e+05  1.45925041e+06
#  -1.60412087e+06 -2.70356131e+05 -2.36902859e+06  1.63748838e+06
#  -8.62124293e+05 -1.92296235e+05  2.67740102e+05 -1.12709482e+06
#  -2.11996222e+05  5.75290938e+05  5.69010301e+05  2.34072349e+05
#  -4.65985932e+06 -6.54467088e+05  9.19028530e+05 -3.81321759e+04
#   1.74585809e+05 -2.49106286e+06  1.35768594e+06 -7.55018492e+05
#   1.15342399e+05  6.64083881e+05  1.32983853e+06  1.53535960e+05
#  -2.50856260e+06 -1.96790253e+06  6.18698243e+04 -3.00566666e+06
#   7.51308942e+05 -4.06427185e+05 -3.03510798e+06 -3.74781929e+05
# ...

# %%
y_pred_test=regressor.predict(x_test)
diff2=(y_pred_test-y_test)
print(diff2)
# Out:
# [-6.73546459e+05  6.08808234e+04  5.21131961e+05  3.02572784e+05
#  -1.27599247e+05  7.39975945e+05 -3.08123684e+05  2.97823377e+05
#  -9.65246705e+03  2.11982669e+05 -1.87642243e+05 -3.07893058e+05
#   6.92743617e+05  1.22744356e+06 -8.33444570e+04 -7.00583278e+05
#  -3.37893601e+05 -8.25143261e+03 -8.18432677e+04  3.43335393e+05
#   9.09006000e+05  9.81142046e+05 -1.65980712e+06  7.88961568e+05
#  -8.12402062e+05  1.96577202e+05 -3.72445085e+05  9.32569007e+05
#   1.72118368e+05 -1.25660211e+05 -9.11611022e+05  2.83205662e+06
#   1.86244657e+06 -3.99015586e+05  8.28135864e+05  4.91195872e+05
#  -4.06107376e+06  2.40632185e+05 -2.71565866e+05 -3.04739107e+05
#  -1.01961419e+06  8.26093896e+05  6.49754687e+05  4.18187002e+05
#   2.07075337e+05 -1.16363971e+06 -1.08221670e+05 -5.83496346e+05
#   4.42253757e+04 -1.79107684e+05 -1.13477308e+05  2.36725818e+06
#  -6.08091940e+05 -8.11747066e+05  2.18086877e+05  7.04842804e+04
# ...

# %%
  #Residual plot - plot y_pred in x axis and errors in y axis

# %%
plt.scatter(y_pred_train,diff1,color='blue')

plt.show()

# %%
plt.scatter(y_pred_test,diff2,color='blue')
plt.show()
